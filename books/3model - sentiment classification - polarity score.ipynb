# %% [markdown]
# # Polarity scorer

# %%
import pandas as pd

# %%
ds = pd.read_csv('../dataset/enwiki/opinions.csv')

# %%
ds.head()
# Out:
#    page_id          page_title contributor   timestamp action topic  \
# 0  7200650  Talk:Rafael Correa      Namiba  1160155122      +   NaN
# 1  7200650  Talk:Rafael Correa         172  1160170921      +   NaN
# 2  7200650  Talk:Rafael Correa         172  1160171084      -   NaN
# 3  7200650  Talk:Rafael Correa         172  1160171084      +   NaN
# 4  7200650  Talk:Rafael Correa     Jun-Dai  1160208202      +   NaN
#
#                                              opinion  \
# 0  I don't see a problem with including campaign ...
# 1  :Please do not revert my clean-up of the artic...
# 2  :Please do not revert my clean-up of the artic...
# 3  :Please do not revert my clean-up of the artic...
# 4  ::Well the sentences you removed certainly wer...
#
#                                        opinion_clean
# 0  I don't see a problem with including campaign ...
# 1   Please do not revert my clean-up of the artic...
# 2   Please do not revert my clean-up of the artic...
# 3   Please do not revert my clean-up of the artic...
# 4    Well the sentences you removed certainly wer...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize

# %%
opinion = ds.opinion[0]
opinion
# Out:
# 'I don\'t see a problem with including campaign "rhetoric". His beliefs are notable. I am reverting.--Thomas.macmillan 17:18, 6 October 2006 (UTC)'

# %%
sentences = tokenize.sent_tokenize(opinion)
sentences
# Out:
# ['I don\'t see a problem with including campaign "rhetoric".',
#  'His beliefs are notable.',
#  'I am reverting.--Thomas.macmillan 17:18, 6 October 2006 (UTC)']

# %%
sid = SentimentIntensityAnalyzer()

for sentence in sentences:
    ss = sid.polarity_scores(sentence)
    print(ss)
# Out:
# {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.3089}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
